# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
# 10 Most visited national parks's visitors  
# !cat /Users/hayley/workspace/scrapyProject/NationalParkVisitation/visitors.csv
# Out:
# num,park_name,visits_number
# 1,Great Smoky Mountains National Park ,"11,421,200 "
# 2,Grand Canyon National Park,"6,380,495 "
# 3,Rocky Mountain National Park,"4,590,493 "
# 4,Zion National Park,"4,320,033 "
# 5,Yellowstone National Park,"4,115,000 "
# 6,Yosemite National Park,"4,009,436 "
# 7,Acadia National Park,"3,537,575 "
# 8,Grand Teton National Park,"3,491,151 "
# 9,Olympic National Park,"3,104,455 "
# 10 ,Glacier National Park,"2,965,309 "

# %%
df_top10_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/NationalParkVisitation/visitors.csv')

# %%
pd.read_csv('/Users/hayley/workspace/scrapyProject/NationalParkVisitation/visitors.csv')
# Out:
#    num                             park_name visits_number
# 0    1  Great Smoky Mountains National Park    11,421,200
# 1    2            Grand Canyon National Park    6,380,495
# 2    3          Rocky Mountain National Park    4,590,493
# 3    4                    Zion National Park    4,320,033
# 4    5             Yellowstone National Park    4,115,000
# 5    6                Yosemite National Park    4,009,436
# 6    7                  Acadia National Park    3,537,575
# 7    8             Grand Teton National Park    3,491,151
# 8    9                 Olympic National Park    3,104,455
# 9   10                 Glacier National Park    2,965,309

# %%
df_top10_visitors
# Out:
#    num                             park_name visits_number
# 0    1  Great Smoky Mountains National Park    11,421,200
# 1    2            Grand Canyon National Park    6,380,495
# 2    3          Rocky Mountain National Park    4,590,493
# 3    4                    Zion National Park    4,320,033
# 4    5             Yellowstone National Park    4,115,000
# 5    6                Yosemite National Park    4,009,436
# 6    7                  Acadia National Park    3,537,575
# 7    8             Grand Teton National Park    3,491,151
# 8    9                 Olympic National Park    3,104,455
# 9   10                 Glacier National Park    2,965,309

# %%
df_top10_visitors.dtypes
# Out:
# num               int64
# park_name        object
# visits_number    object
# dtype: object

# %%
#data handling and cleansing
df_top10_visitors['visits_number'].astype(str)
# Out:
# 0    11,421,200
# 1     6,380,495
# 2     4,590,493
# 3     4,320,033
# 4     4,115,000
# 5     4,009,436
# 6     3,537,575
# 7     3,491,151
# 8     3,104,455
# 9     2,965,309
# Name: visits_number, dtype: object

# %%
df_top10_visitors['visits_number'] = df_top10_visitors['visits_number'].apply(lambda x: x.replace(',','')).astype('int')

# %%
df_top10_visitors['park_name'].apply(lambda x: x.replace('National Park','NP'))
# Out:
# 0    Great Smoky Mountains NP
# 1              Grand Canyon NP
# 2            Rocky Mountain NP
# 3                      Zion NP
# 4               Yellowstone NP
# 5                  Yosemite NP
# 6                    Acadia NP
# 7               Grand Teton NP
# 8                   Olympic NP
# 9                   Glacier NP
# Name: park_name, dtype: object

# %%
# set index 
df_top10_visitors['park_name'] = df_top10_visitors['park_name'].apply(lambda x: x.replace('National Park','NP'))
df_top10_visitors.set_index("park_name",inplace=True)

# %%
# 10 Most visited national parks's visitors  
df_top10_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/NationalParkVisitation/visitors.csv')

#data handling and cleansing
# visit number  remove ',' and convert type object-> int 
df_top10_visitors['visits_number'].astype(str)
df_top10_visitors['visits_number'] = df_top10_visitors['visits_number'].apply(lambda x: x.replace(',','')).astype('int')

# park name editing
df_top10_visitors['park_name'].apply(lambda x: x.replace('National Park','NP'))

#set index 
df_top10_visitors['park_name'] = df_top10_visitors['park_name'].apply(lambda x: x.replace('National Park','NP'))
df_top10_visitors.set_index("park_name",inplace=True)


# draw graph 
plot_top10_visitors= df_top10_visitors['visits_number'].plot(kind='bar',stacked=True,figsize=(10,7), color=plt.cm.Paired(np.arange(len(df_top10_visitors))));

plot_top10_visitors.set_title("10 Most Visited National Parks in 2018", fontsize=15)
 
## x axis label 
plot_top10_visitors.set_xlabel("Natioanl Park Name")
 
# y axis label
plot_top10_visitors.set_ylabel("Visitors")
plot_top10_visitors.set_yticks(np.arange(0, 12000000, step=1000000))
# Out:
# [<matplotlib.axis.YTick at 0x1a1da6be80>,
#  <matplotlib.axis.YTick at 0x1a1da87320>,
#  <matplotlib.axis.YTick at 0x1a1d786d68>,
#  <matplotlib.axis.YTick at 0x1a1d787c88>,
#  <matplotlib.axis.YTick at 0x1a1d8f9f28>,
#  <matplotlib.axis.YTick at 0x1a1d7a7438>,
#  <matplotlib.axis.YTick at 0x1a1d7a7da0>,
#  <matplotlib.axis.YTick at 0x1a1dac9320>,
#  <matplotlib.axis.YTick at 0x1a1d7f7208>,
#  <matplotlib.axis.YTick at 0x1a1d7f7438>,
#  <matplotlib.axis.YTick at 0x1a1d5d4ba8>,
#  <matplotlib.axis.YTick at 0x1a1d7e1b38>]

# %%
# 10 Most visited national parks visitors each month
# !cat /Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_ZionNP.csv
# Out:
# ﻿Name,Textbox3
# "Zion NP
# Recreation Visits",Bookmark this report: https://irma.nps.gov/Stats/SSRSReports/Park%20Specific%20Reports/Visitation%20by%20Month
#
# Year,JAN,FEB,MAR,APR,MAY,JUN,JUL,AUG,SEP,OCT,NOV,DEC
# 2018,"107,960","127,790","373,523","483,487","500,118","541,464","500,350","459,415","481,507","377,826","218,799","147,794"
# 2017,"88,561","110,569","345,476","515,652","509,017","533,252","576,349","529,684","512,940","422,377","222,069","138,866"
# 2016,"84,145","117,510","359,920","395,768","447,976","544,890","599,961","477,507","497,825","412,916","232,271","124,438"
# 2015,"78,318","106,314","291,118","392,417","400,048","458,546","479,538","455,487","394,201","314,966","180,390","97,503"
# 2014,"70,862","74,625","226,424","312,381","391,969","397,753","407,153","391,973","340,855","304,108","169,607","101,986"
# 2013,"56,972","64,994","227,899","292,765","313,594","367,217","379,129","345,014","339,593","203,056","141,251","75,903"
# 2012,"68,202","74,382","165,242","352,192","343,488","370,280","392,359","364,857","355,140","276,134","140,350","70,981"
# 2011,"64,524","67,801","164,037","255,813","325,089","376,453","391,144","360,196","324,727","273,876","145,158","76,687"
# 2010,"54,928","62,099","171,079","277,599","304,278","331,185","362,881","332,796","319,838","236,316","143,272","69,701"
# 2009,"60,204","62,964","167,246","271,709","296,330","366,004","368,933","372,157","306,161","265,095","132,998","65,601"
# 2008,"56,137","62,044","187,814","242,778","302,002","354,527","360,046","368,739","312,606","254,187","126,588","62,686"
# 2007,"68,640","71,530","176,622","286,701","281,149","333,005","338,116","337,824","314,290","253,572","129,962","65,870"
# 2006,"71,680","70,170","144,186","264,821","277,849","325,124","347,105","337,212","298,587","235,952","128,339","66,325"
# 2005,"63,566","70,260","195,530","230,366","283,547","339,849","347,745","340,826","298,465","227,570","118,083","70,858"
# 2004,"67,913","81,970","190,919","297,906","295,304","326,499","337,145","338,899","323,156","227,332","113,626","76,673"
# 2003,"71,233","72,781","143,284","244,910","304,556","308,634","294,996","312,162","280,970","229,992","119,860","75,414"
# 2002,"55,866","66,575","158,518","279,225","301,163","329,355","347,541","322,920","312,931","229,989","112,489","75,973"
# 2001,"61,795","53,960","95,231","207,864","210,707","323,759","321,920","344,531","261,476","179,932","105,821","50,783"
# 2000,"80,141","73,390","126,843","220,905","239,579","341,054","341,050","331,474","289,827","232,685","105,733","49,667"
# 1999,"73,220","69,337","122,668","218,059","218,639","298,448","335,012","373,744","309,215","237,279","124,086","69,957"
# 1998,"70,167","62,429","112,119","201,553","230,959","325,129","318,876","359,490","284,343","229,844","112,117","63,022"
# 1997,"65,244","68,431","128,143","230,390","226,370","326,154","333,883","367,010","304,847","230,274","104,605","60,183"
# 1996,"58,277","70,136","126,044","237,607","238,705","339,727","340,812","372,426","310,840","239,701","102,777","60,949"
# 1995,"60,215","70,317","119,841","189,511","202,000","337,268","363,645","377,107","312,443","224,457","119,920","53,438"
# 1994,"60,598","55,083","103,289","205,846","198,731","304,478","326,536","361,394","295,720","221,345","90,568","47,283"
# 1993,"52,236","50,599","106,142","206,549","220,669","335,945","348,106","376,382","290,893","258,341","92,657","54,061"
# 1992,"55,002","58,579","81,606","138,140","257,471","338,363","353,454","415,549","318,549","225,259","89,896","58,758"
# 1991,"54,687","64,780","71,951","131,160","255,396","336,422","349,020","362,064","278,614","208,030","80,061","44,812"
# 1990,"54,093","48,346","77,423","154,762","237,277","316,983","308,335","340,603","257,272","166,148","98,844","42,314"
# 1989,"33,534","38,254","94,224","132,387","235,179","300,330","304,532","321,244","248,105","163,695","86,055","41,317"
# 1988,"38,333","46,684","65,640","129,748","208,323","308,566","305,583","314,482","262,166","157,715","71,847","39,245"
# 1987,"35,783","37,091","57,095","117,924","203,914","267,237","296,526","300,993","231,095","131,044","61,714","37,203"
# 1986,"35,763","35,919","80,728","92,993","246,440","252,715","261,818","269,267","194,138","110,052","50,783","39,887"
# 1985,"23,339","30,716","54,763","95,748","201,599","229,265","253,508","253,802","182,744","100,050","44,125","33,613"
# 1984,"21,848","26,463","48,492","89,509","160,492","231,037","232,872","226,230","174,514","102,092","42,409","21,296"
# 1983,"18,578","24,133","36,086","75,772","183,803","201,746","227,243","202,119","154,567","90,204","37,866","20,913"
# 1982,"15,445","20,958","38,731","72,295","146,438","221,168","252,010","196,725","140,672","85,304","32,936","23,608"
# 1981,"24,349","22,594","35,058","63,036","132,198","221,905","233,041","262,514","150,219","86,905","34,820","22,169"
# 1980,"15,637","17,832","32,537","58,225","134,747","175,129","212,492","212,223","136,648","75,312","32,542","20,522"
# 1979,"8,994","12,106","23,079","63,306","122,964","156,734","168,614","187,461","173,883","77,131","29,139","17,117"

# %%
# 10 Most visited national parks visitors by month

from matplotlib import pyplot as plt
from cycler import cycler
plt.style.use('ggplot')

# read csv files 
df_ZionNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_ZionNP.csv', skiprows=3)
df_AcadiaNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_AcadiaNP.csv', skiprows=3)
df_GlacierNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_GlacierNP.csv', skiprows=3)
df_GrandCanyonNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_GrandCanyonNP.csv', skiprows=3)
df_GrandTetonNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_GrandTetonNP.csv', skiprows=3)
df_GreatSmokyMountainsNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_GreatSmokyMountainsNP.csv', skiprows=3)
df_OlympicNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_OlympicNP.csv', skiprows=3)
df_RockyMountainNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_RockyMountainNP.csv', skiprows=3)
df_YellowstoneNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_YellowstoneNP.csv', skiprows=3)
df_YosemiteNP_visitors = pd.read_csv('/Users/hayley/workspace/scrapyProject/CSV/VisitationbyMonth_Yosemite.csv', skiprows=3)

# data cleansing , convert data type, set index, draw graph 
df_np_names = [df_AcadiaNP_visitors, df_ZionNP_visitors,df_GlacierNP_visitors,df_GrandCanyonNP_visitors,df_GrandTetonNP_visitors,df_GreatSmokyMountainsNP_visitors,df_OlympicNP_visitors,df_RockyMountainNP_visitors,df_YellowstoneNP_visitors,df_YosemiteNP_visitors]
np_name = ["Acadia NP", "Zion NP", "Glacier NP", "Grand Canyon NP", "Grand Teton NP", "Great Smoky Mountains NP", "Olympic NP", "Rocky Mountain NP", "Yellowstone NP", "Yosemite NP"]
#colors = ['b', 'c', 'y', 'm', 'r']
plt.figure(figsize=(20,10))
#colormap = plt.cm.gist_ncar
#plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, num_plots)])

#plt.gca().set_prop_cycle('color', color_list)
#.set_color_cycle(['kbkykrkg'])
#color=plt.cm.Paired(np.arange(len(df_np_names))
#num_plots = 10
#colormap = plt.cm.gist_ncar
#plt.gca().set_prop_cycle([colormap(i) for i in np.linspace(0, 0.9, num_plots)])

num_colors = 10

cm = plt.get_cmap('Accent')
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_prop_cycle('color', [cm(1.*i/num_colors) for i in range(num_colors)])


for i,df_np_name in enumerate(df_np_names):
    for col_name in df_np_name.columns:
        if col_name == 'Year':
            continue
        df_np_name[col_name] = df_np_name[col_name].astype('str').apply(lambda x: x.replace(',','')).astype('int')
    print(np_name[i])
    #plt.plot(df_np_name.set_index('Year').T[2018],'o-',label=np_name[i])
    df_np_name = df_np_name.set_index('Year')
    plt.plot(df_np_name.T[2018],'o-',label=np_name[i])
    
plt.legend()
plt.show()
# Out:
# Acadia NP
# Zion NP
# Glacier NP
# Grand Canyon NP
# Grand Teton NP
# Great Smoky Mountains NP
# Olympic NP
# Rocky Mountain NP
# Yellowstone NP
# Yosemite NP

# %%
test = df_AcadiaNP_visitors.set_index('Year').T
#test.reset_index()

#test
#plt.plot(test[2018],'o-')
#plt.plot(test[2017],'o-')

#plt.show()
#test[2018]
#test['Year']

# %%
# national park fee 
from matplotlib import pyplot as plt
plt.style.use('ggplot')


# read csv files 
df_np_fee = pd.read_csv('/Users/hayley/workspace/scrapyProject/NationalParkEntranceFee/entranceFee.csv',encoding="ISO-8859-1")

#data cleansing time column

def convert_date(time):
    result = time
    
    #1.Jan.19 -> 20190119
    if(time=='Current'):
        result = '20181231' 
        
    else:
        dict_month = {"Jan": "01", "May": "05"}
        tmp = ('20',time.split(".")[2],dict_month[time.split(".")[1]],'0',time.split(".")[0])
        result = "".join(tmp)
   
    return result


#df_np_fee["time"].apply(lambda x: x.replace(',','')).astype('int')
df_np_fee["time"] = df_np_fee["time"].apply(convert_date)

df_np_fee = df_np_fee[df_np_fee["time"] < '20190720'] 
df_np_fee["tmp"] = df_np_fee.groupby(['park_name'])['time'].transform(max)
df_np_fee = df_np_fee[df_np_fee["time"] == df_np_fee["tmp"]] 

df_np_fee = df_np_fee.drop_duplicates()

df_np_fee['per_person'] = df_np_fee['per_person'].apply(lambda x: (x.replace('$','')) or (x.strip().replace('',0))).astype('int')
#df_np_fee['annual_pass'] = df_np_fee['annual_pass'].apply(lambda x: (x.replace('$','')) or (x.replace(' ',0)))
df_np_fee['annual_pass'] = df_np_fee['annual_pass'].apply(lambda x: (x.replace('$','')) or (x.strip().replace('',0)))

# park name editing
df_np_fee['park_name'] = df_np_fee['park_name'].apply(lambda x: x.replace('National Park','NP'))

#Great Smoky Mountains fee is free. Insert Great Smoky Mountains's data!
df_greatsmoky = pd.DataFrame({'annual_pass':[0],
                              'park_name': ['Great Smoky Mountains NP'],
                              'per_motorcycle': [0], 
                              'per_person' : [0], 
                              'per_vehicle': [0],
                              'time' : ['20181231'],
                              'tmp':['20181231']})
                             #[[647,0,'Great Smoky Mountains NP',0,0,0,'20181231','20181231']])

df_np_fee = pd.concat([df_np_fee,df_greatsmoky], axis=0)
#print(df_np_fee)

#top10_df_np_fee = df_np_fee[df_np_fee["park_name"].isin(np_name)]
top10_df_np_fee = df_np_fee[df_np_fee["park_name"].isin(np_name)]

top10_df_np_fee.set_index("park_name",inplace=True)

top10_df_np_fee['annual_pass'] = top10_df_np_fee['annual_pass'].astype('int')

#top10_df_np_fee.drop('tmp', axis=1, inplace=True)

top10_df_np_fee = top10_df_np_fee.sort_values('per_person',ascending=False)

# draw graph 
plot_top10_np_fee = top10_df_np_fee.plot(kind='barh',figsize=(8,6), color=plt.cm.Paired(np.arange(len(top10_df_np_fee))));

#plt.plot(top10_df_np_fee,kind='bar')
#plt.plot(top10_df_np_fee,kind='bar',stacked=True,figsize=(10,7), color=plt.cm.Paired(np.arange(len(top10_df_np_fee))))
    
    
#op10_df_np_fee= top10_df_np_fee['visits_number'].plot(kind='bar',stacked=True,figsize=(10,7), color=plt.cm.Paired(np.arange(len(df_top10_visitors))));

plot_top10_np_fee.set_title("10 Most Visited National Parks's Entrance Fee", fontsize=20)
 
## x axis label 
plot_top10_np_fee.set_xlabel("Entrance Fee")
 
# y axis label
plot_top10_np_fee.set_ylabel("Natioanl Park Name")
#plot_top10_visitors.set_yticks(np.arange(0, 12000000, step=1000000))

#plot.show()

'''
# .astype('int')

#df_np_fee.sort_values('per_person',ascending=False)
.

#np_name = ["Acadia NP", "Zion NP", "Glacier NP", "Grand Canyon NP", "Grand Teton NP", "Great Smoky Mountains NP", "Olympic NP", "Rocky Mountain NP", "Yellowstone NP", "Yosemite NP"]

#print(df_np_fee[df_np_fee["park_name"].isin(np_name)])

# draw graph 10 most national parks's fee 

#top10_df_np_fee = df_np_fee[df_np_fee["park_name"].item in np_name]

top10_df_np_fee = df_np_fee[df_np_fee["park_name"].isin(np_name)]


print(top10_df_np_fee.sort_values('park_name',ascending=True))


#set index 
df_np_fee.set_index("park_name",inplace=True)


# draw graph 
plot_top10_visitors= df_top10_visitors['visits_number'].plot(kind='bar',stacked=True,figsize=(10,7), color=plt.cm.Paired(np.arange(len(df_top10_visitors))));

plot_top10_visitors.set_title("10 Most Visited National Parks in 2018", fontsize=20)
 
## x axis label 
plot_top10_visitors.set_xlabel("Natioanl Park Name")
 
# y axis label
plot_top10_visitors.set_ylabel("Visitors")
plot_top10_visitors.set_yticks(np.arange(0, 12000000, step=1000000))
'''


top10_df_np_fee
# Out:
# /Users/hayley/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                           annual_pass per_motorcycle  per_person per_vehicle  \
# park_name
# Glacier NP                         70           $30           20        $35
# Grand Canyon NP                    70           $30           20        $35
# Grand Teton NP                     70           $30           20        $35
# Rocky Mountain NP                  70           $30           20        $35
# Yellowstone NP                     70           $30           20        $35
# Yosemite NP                        70           $30           20        $35
# Zion NP                            70           $30           20        $35
# Acadia NP                          55           $25           15        $30
# Olympic NP                         55           $25           15        $30
# Great Smoky Mountains NP            0              0           0           0
#
#                               time       tmp
# park_name
# Glacier NP                20181231  20181231
# Grand Canyon NP           20181231  20181231
# Grand Teton NP            20181231  20181231
# Rocky Mountain NP         20181231  20181231
# Yellowstone NP            20181231  20181231
# Yosemite NP               20181231  20181231
# Zion NP                   20181231  20181231
# Acadia NP                 20181231  20181231
# Olympic NP                20181231  20181231
# Great Smoky Mountains NP  20181231  20181231

# %%
#data cleansing

def convert_date(time):
    result = time
    
    #1.Jan.19
    if(time=='Current'):
        result = '20181231' 
        
    else:
        dict_month = {"Jan": "01", "May": "05"}
        tmp = ('20',time.split(".")[2],dict_month[time.split(".")[1]],'0',time.split(".")[0])
        result = "".join(tmp)
   
    return result

# %%
#df_np_fee.loc[3]["time"].split(".")
#df_AcadiaNP_visitors.set_index("Year").sum(axis = 0, skipna = True)
df_AcadiaNP_visitors = df_AcadiaNP_visitors.set_index("Year")
df_AcadiaNP_visitors["sum"] = df_AcadiaNP_visitors.sum(axis = 1, skipna = True)
df_AcadiaNP_visitors
# Out:
#         JAN    FEB    MAR     APR     MAY     JUN     JUL      AUG     SEP  \
# Year
# 2018  11974  12167  23756   72858  249050  499163  759165   767219  600397
# 2017  15520  14342  20936   85267  222978  476191  743529   762436  595388
# 2016  17204  16530  28121   94199  217147  445410  696854   735945  570434
# 2015  12578  10626  18062   63214  187205  359661  606597   666767  479320
# 2014  10459  10258  17502   57211  153013  338845  561073   638152  418173
# 2013  11249   9869  20631   47090  133653  315791  555308   617306  400400
# 2012  11930  12388  22684   59471  157406  309198  539234   574307  391810
# 2011  10428   9533  19510   58307  132720  297222  559892   583153  387868
# 2010  10510  13398  26080   57992  169898  286635  545382   627918  431001
# 2009   9366   9751  19258   59277  129885  244780  457622   586446  399789
# 2008  10744  11131  17489   53798  125679  263542  470295   514443  319582
# 2007  12415  11068  19220   61775  132152  273765  461894   544892  371217
# 2006  13494  12924  21695   59034  120889  244333  476631   506833  330649
# 2005  10810  11831  18917   59773  110330  275175  468512   519350  321070
# 2004  11861  14266  20952   60180  134597  305134  471406   524675  357146
# 2003  22917  21993  34274   68444  135443  309230  547836   595191  376060
# 2002  15309  25071  34498   72528  163145  325441  571119   636824  392531
# 2001  18090  23926  35473   76007  157353  325242  558641   630240  377456
# 2000  22500  23848  35423   78555  166456  319208  547929   594904  378135
# 1999  16430  17162  33688   82993  174610  315980  562996   639073  426024
# 1998  16726  17028  27500   81896  148052  307208  565477   701097  391378
# 1997  16292  17230  27035   77005  132194  340064  622847   758140  404808
# 1996  17655  15576  32452   76597  166290  327723  571017   714090  426562
# 1995  14894  20510  32120   86198  175550  355270  626947   753799  439553
# 1994  13364  18112  29086   58788  182781  311803  617622   720079  421106
# 1993  19402  15556  29040   57707  192823  300647  586449   719671  417317
# 1992  17510  21110  30312   63276  164400  262173  539109   615843  391798
# 1991  24588  14667  31291   75738  157252  295348  574529   640990  377904
# 1990  16084  13383  30060   17898  148090  290533  554953   645522  355864
# 1989  41114  42012  74773  324714  579272  704488  999535  1045060  666669
# 1988  43462  30060  54253  223653  448299  582015  799802   909762  601530
# 1987  35579  35766  56924  292358  444265  523486  751309   786970  562309
# 1986  28369  33055  47390  257926  411604  486835  717864   809273  488247
# 1985  31360  23261  46315  261410  341775  432926  725951   816294  451026
# 1984  24273  26185  37289  229638  271964  458908  790392   865843  443622
# 1983  23771  24667  25576  207347  287861  435142  916474   715624  668981
# 1982  21425  22210  36866  193208  261452  404915  737860   574164  541721
# 1981  23330  16207  21923  188071  212500  366518  545981   616233  463823
# 1980   8966   8225   7505  182879  209301  359552  533885   633067  282636
# 1979   6011   5243  11165  219351  339416  543205  383341   466928  320138
#
#          OCT     NOV    DEC         sum
# Year
# 2018  488204   40930  12692   7077168.0
# 2017  507594   53006  12084   7020559.0
# 2016  412416   55022  14111   6608802.0
# 2015  344362   48912  13880   5624383.0
# 2014  313920   31013  13510   5128272.0
# 2013   94904   41181   7540   4511857.0
# 2012  302932   38385  11307   4864116.0
# 2011  270477   34192  11343   4751301.0
# 2010  289114   36736   9544   5010426.0
# 2009  258007   44042   9475   4457405.0
# 2008  246533   32759   9862   4153722.0
# 2007  263311   41449   9070   4406463.0
# 2006  249850   33903  13353   4169182.0
# 2005  207599   37101  11016   4104973.0
# 2004  261284   34125  12221   4417698.0
# 2003  262412   44294  12968   4864127.0
# 2002  271312   36589  14205   5119146.0
# 2001  257280   41353  15490   5035103.0
# 2000  253626   33693  14961   4940476.0
# 1999  277644   39416  16211   5206453.0
# 1998  266138   55225  16772   5190992.0
# 1997  287171   57810  19710   5522609.0
# 1996  280577   56828  19464   5411658.0
# 1995  271606   54121  14810   5692751.0
# 1994  268779   48907  20322   5423492.0
# 1993  254615   43755  19052   5314061.0
# 1992  211573   46316  18693   4766218.0
# 1991  224497   45518  13535   4953705.0
# 1990  207770   47633  11801   4681172.0
# 1989  610334  302857  50124  10883893.0
# 1988  455637  303503  50307   9006554.0
# 1987  444810  299699  54679   8578295.0
# 1986  407396  204770  36325   7860094.0
# 1985  373037  206970  35245   7493125.0
# 1984  361873  194735  30041   7471510.0
# 1983  529524  262444  27228   8251261.0
# 1982  446170  303753  28370   7146210.0
# 1981  313788  203741  25857   5997925.0
# 1980  332937  200461  20252   5561312.0
# 1979  300976  183750   7842   5576711.0

# %%
# visitors history 

from matplotlib import pyplot as plt
plt.style.use('ggplot')

# data cleansing , convert data type, set index, draw graph 
df_np_names = [ df_ZionNP_visitors,df_GlacierNP_visitors,df_AcadiaNP_visitors, df_GrandCanyonNP_visitors,df_GrandTetonNP_visitors,df_GreatSmokyMountainsNP_visitors,df_OlympicNP_visitors,df_RockyMountainNP_visitors,df_YellowstoneNP_visitors,df_YosemiteNP_visitors]
np_name = [ "Zion NP", "Glacier NP", "Acadia NP", "Grand Canyon NP", "Grand Teton NP", "Great Smoky Mountains NP", "Olympic NP", "Rocky Mountain NP", "Yellowstone NP", "Yosemite NP"]


#df_AcadiaNP_visitors = df_AcadiaNP_visitors.set_index("Year")
#df_AcadiaNP_visitors["sum"] = df_AcadiaNP_visitors.sum(axis = 1, skipna = True)
#df_AcadiaNP_visitors



plt.figure(figsize=(20,10))

num_colors = 10

cm = plt.get_cmap('Set1')
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.set_prop_cycle('color', [cm(1.*i/num_colors) for i in range(num_colors)])

#colormap = plt.cm.gist_ncar
#plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, num_plots)])

#plt.gca().set_prop_cycle('color', color_list)
#.set_color_cycle(['kbkykrkg'])
#color=plt.cm.Paired(np.arange(len(df_np_names))

for i,df_np_name in enumerate(df_np_names):
    '''
    for col_name in df_np_name.columns:
        if col_name == 'Year':
            continue
        df_np_name[col_name] = df_np_name[col_name].astype('str').apply(lambda x: x.replace(',','')).astype('int')
    '''
    #print(np_name[i])
    #plt.plot(df_np_name.set_index('Year').T[2018],'o-',label=np_name[i])
    
    #print(df_np_name)
    df_np_name = df_np_name.set_index('Year')
    df_np_name["sum"] = df_np_name.sum(axis = 1, skipna = True)

    plt.plot(df_np_name["sum"],'o-',label=np_name[i])
    
    


#df_ZionNP_visitors['visits_number'].plot(kind='bar',stacked=True,figsize=(10,7), color=plt.cm.Paired(np.arange(len(df_top10_visitors))));
#df_ZionNP_visitors_2018.plot(figsize=(10,7), color=plt.cm.Paired(np.arange(len(df_top10_visitors))));

plt.legend()
plt.show()

# %%
df_np_fee
# Out:
#     annual_pass                                          park_name  \
# 0           55                                           Acadia NP
# 1           45                      Adams National Historical Park
# 3           30                       Antietam National Battlefield
# 5           55                                           Arches NP
# 6           40                 Assateague Island National Seashore
# 9           50                                         Badlands NP
# 11          45                         Bandelier National Monument
# 12          55                                         Big Bend NP
# 13          40                     Black Canyon of the Gunnison NP
# 15          40                                     Bryce Canyon NP
# 17          35                          Cabrillo National Monument
# 19          40                         Canaveral National Seashore
# 21          55                                      Canyonlands NP
# 23          60                          Cape Cod National Seashore
# 26          35                                     Capitol Reef NP
# 28          35                   Capulin Volcano National Monument
# 30                                             Carlsbad Caverns NP
# 31          45            Castillo De San Marcos National Monument
# 32          30                      Cedar Breaks National Monument
# 34                          Chaco Culture National Historical Park
# 36          30    Chesapeake & Ohio Canal National Historical Park
# 39          35    Chickamauga & Chattanooga National Military Park
# 40                            Christiansted National Historic Site
# 43          40                   Colonial National Historical Park
# 46          40                          Colorado National Monument
# 48          50                                      Crater Lake NP
# 50          35   Craters of the Moon National Monument and Pres...
# 51          35                 Cumberland Island National Seashore
# 52          55                                     Death Valley NP
# 54          45                                Denali NP & Preserve
# ..          ...                                                ...
# 438                                  Pipe Spring National Monument
# 440         30                          Prince William Forest Park
# 442         50      Pu'uhonua O HÅnaunau National Historical Park
# 444         70                                   Rocky Mountain NP
# 445         40                Sagamore Hill National Historic Site
# 447         40                                          Saguaro NP
# 449         40                Saint Gaudens National Historic Site
# 450         45     San Francisco Maritime National Historical Park
# 451         25                     San Juan National Historic Site
# 453         60                            Sequoia-Kings Canyon NPs
# 454         55                                       Shenandoah NP
# 456         45              Sleeping Bear Dunes National Lakeshore
# 457         45             Sunset Crater Volcano National Monument
# 458         55                               Theodore Roosevelt NP
# 459         45              Thomas Edison National Historical Park
# 461                                        Tonto National Monument
# 462         30                       TumacÃ¡cori National Monument
# 465         45                          Tuzigoot National Monument
# 632                      Vanderbilt Mansion National Historic Site
# 633         35                    Vicksburg National Military Park
# 635         45                     Walnut Canyon National Monument
# 637         45                Whiskeytown National Recreation Area
# 639         40                       White Sands National Monument
# 641         35                 Wilson's Creek National Battlefield
# 642         35                   Wright Brothers National Memorial
# 643         45                           Wupatki National Monument
# 644         70                                      Yellowstone NP
# 645         70                                         Yosemite NP
# 646         70                                             Zion NP
# 0             0                           Great Smoky Mountains NP
#
#     per_motorcycle  per_person per_vehicle      time       tmp
# 0             $25           15        $30   20181231  20181231
# 1                           15              20181231  20181231
# 3             $10            7        $15   20190101  20190101
# 5             $25           15        $30   20181231  20181231
# 6             $15           10        $20   20181231  20181231
# 9             $15           12        $25   20190101  20190101
# 11            $20           15        $25   20181231  20181231
# 12            $25           15        $30   20181231  20181231
# 13            $15           10        $20   20181231  20181231
# 15            $30           20        $35   20181231  20181231
# 17            $15           10        $20   20190101  20190101
# 19            $10            5        $15   20190101  20190101
# 21            $25           15        $30   20181231  20181231
# 23            $15           10        $20   20190101  20190101
# 26            $15           10        $20   20190101  20190101
# 28            $15           10        $20   20190101  20190101
# 30                          15              20190101  20190101
# 31                          15              20181231  20181231
# 32                           7              20181231  20181231
# 34            $20           15        $25   20181231  20181231
# 36            $10            7        $15   20190101  20190101
# 39                          10              20190101  20190101
# 40                           7              20181231  20181231
# 43                          10              20190101  20190101
# 46            $15           10        $20   20190101  20190101
# 48            $20           12        $25   20181231  20181231
# 50            $15           10        $20   20181231  20181231
# 51                          10              20181231  20181231
# 52            $25           15        $30   20181231  20181231
# 54                          15              20190501  20190501
# ..             ...         ...         ...       ...       ...
# 438                         10              20181231  20181231
# 440           $10            7        $15   20190101  20190101
# 442           $10            7        $15   20181231  20181231
# 444           $30           20        $35   20181231  20181231
# 445                         10              20181231  20181231
# 447           $15           10        $20   20190101  20190101
# 449                         10              20181231  20181231
# 450                         15              20181231  20181231
# 451                          7              20181231  20181231
# 453           $30           20        $35   20181231  20181231
# 454           $25           15        $30   20181231  20181231
# 456           $20           15        $25   20190101  20190101
# 457           $20           15        $25   20181231  20181231
# 458           $25           15        $30   20181231  20181231
# 459                         15              20181231  20181231
# 461                         10              20190101  20190101
# 462                          7              20181231  20181231
# 465                         15              20190101  20190101
# 632                         10              20181231  20181231
# 633           $15           10        $20   20181231  20181231
# 635                         15              20190101  20190101
# 637           $20           15        $25   20190101  20190101
# 639           $15           10        $20   20190101  20190101
# 641           $15           10        $20   20181231  20181231
# 642                         10              20181231  20181231
# 643           $20           15        $25   20181231  20181231
# 644           $30           20        $35   20181231  20181231
# 645           $30           20        $35   20181231  20181231
# 646           $30           20        $35   20181231  20181231
# 0                0           0           0  20181231  20181231
#
# [107 rows x 7 columns]

# %%
# scatter plot visitors and entrance fee 
from matplotlib import pyplot as plt
import seaborn as sns

# read csv files 
df_visitors_all = pd.read_csv('/Users/hayley/workspace/scrapyProject/npwiki/npwiki/np_visitors_62.csv')


# visit number  remove ',' and convert type object-> int 
df_visitors_all['visitor'].astype(str)
df_visitors_all['visitor'] = df_visitors_all['visitor'].apply(lambda x: x.replace(',','')).astype('int')

# column rename
df_visitors_all = df_visitors_all.rename(columns = {'name': 'park_name_edit'})
df_visitors_all['park_name_edit'] = df_visitors_all['park_name_edit'].apply(lambda x: x.strip())
#df_np_fee["per_person"]

# park name editing
df_np_fee['park_name_edit'] = df_np_fee['park_name'].apply(lambda x: x.replace('NP','').strip())
df_np_fee.reset_index()
#df_np_fee.reset_index()
#result = pd.concat([df_np_fee, df_visitors_all], axis=1, sort=False, join='inner')
#result = pd.concat([df1, df4], axis=1).reindex(df1.index)
#result
df_merge_fee_visitors = df_np_fee.merge(df_visitors_all, on='park_name_edit', how='inner')


plt.figure(figsize=(8,5))
plt.scatter(df_merge_fee_visitors['per_person'], df_merge_fee_visitors['visitor'],cmap=plt.cm.RdYlGn)
plt.xlabel('per_person')
plt.ylabel('visitor')


sns.lmplot("per_person", "visitor", df_merge_fee_visitors[df_merge_fee_visitors["park_name_edit"] != 'Great Smoky Mountains'])

# %%
df_merge_fee_visitors
# Out:
#    annual_pass                        park_name per_motorcycle  per_person  \
# 0          55                         Acadia NP           $25           15
# 1          55                         Arches NP           $25           15
# 2          50                       Badlands NP           $15           12
# 3          55                       Big Bend NP           $25           15
# 4          40   Black Canyon of the Gunnison NP           $15           10
# 5          40                   Bryce Canyon NP           $30           20
# 6          55                    Canyonlands NP           $25           15
# 7          35                   Capitol Reef NP           $15           10
# 8                           Carlsbad Caverns NP                         15
# 9          50                    Crater Lake NP           $20           12
# 10         55                   Death Valley NP           $25           15
# 11                              Dry Tortugas NP                         15
# 12         55                     Everglades NP           $25           15
# 13         70                        Glacier NP           $30           20
# 14         70                   Grand Canyon NP           $30           20
# 15         70                    Grand Teton NP           $30           20
# 16         30            Guadalupe Mountains NP                          7
# 17         60                    Isle Royale NP                          7
# 18         55                    Joshua Tree NP           $25           15
# 19         55                Lassen Volcanic NP           $25           15
# 20         50                     Mesa Verde NP           $20           12
# 21         55                  Mount Rainier NP           $25           15
# 22         55                        Olympic NP           $25           15
# 23         40               Petrified Forest NP           $15           10
# 24         70                 Rocky Mountain NP           $30           20
# 25         40                        Saguaro NP           $15           10
# 26         55                     Shenandoah NP           $25           15
# 27         55             Theodore Roosevelt NP           $25           15
# 28         70                    Yellowstone NP           $30           20
# 29         70                       Yosemite NP           $30           20
# 30         70                           Zion NP           $30           20
# 31           0         Great Smoky Mountains NP              0           0
#
#    per_vehicle      time       tmp                park_name_edit   visitor
# 0         $30   20181231  20181231                        Acadia   3537575
# 1         $30   20181231  20181231                        Arches   1663557
# 2         $25   20190101  20190101                      Badlands   1008942
# 3         $30   20181231  20181231                      Big Bend    440091
# 4         $20   20181231  20181231  Black Canyon of the Gunnison    308962
# 5         $35   20181231  20181231                  Bryce Canyon   2679478
# 6         $30   20181231  20181231                   Canyonlands    739449
# 7         $20   20190101  20190101                  Capitol Reef   1227627
# 8               20190101  20190101              Carlsbad Caverns    465912
# 9         $25   20181231  20181231                   Crater Lake    720659
# 10        $30   20181231  20181231                  Death Valley   1678660
# 11              20181231  20181231                  Dry Tortugas     56810
# 12        $30   20190101  20190101                    Everglades    597124
# 13        $35   20181231  20181231                       Glacier   2965309
# 14        $35   20181231  20181231                  Grand Canyon   6380495
# 15        $35   20181231  20181231                   Grand Teton   3491151
# 16              20190101  20190101           Guadalupe Mountains    172347
# 17              20181231  20181231                   Isle Royale     25798
# 18        $30   20181231  20181231                   Joshua Tree   2942382
# 19        $30   20190101  20190101               Lassen Volcanic    499435
# 20        $25   20190101  20190101                    Mesa Verde    563420
# 21        $30   20181231  20181231                 Mount Rainier   1518491
# 22        $30   20181231  20181231                       Olympic   3104455
# 23        $20   20181231  20181231              Petrified Forest    644922
# 24        $35   20181231  20181231                Rocky Mountain   4590493
# 25        $20   20190101  20190101                       Saguaro    957405
# 26        $30   20181231  20181231                    Shenandoah   1264880
# 27        $30   20181231  20181231            Theodore Roosevelt    749389
# 28        $35   20181231  20181231                   Yellowstone   4115000
# 29        $35   20181231  20181231                      Yosemite   4009436
# 30        $35   20181231  20181231                          Zion   4320033
# 31           0  20181231  20181231         Great Smoky Mountains  11421200

# %%
df_visitors_all
# Out:
#                   park_name_edit   visitor
# 0                         Acadia   3537575
# 1                 American Samoa     28626
# 2                         Arches   1663557
# 3                       Badlands   1008942
# 4                       Big Bend    440091
# 5                       Biscayne    469253
# 6   Black Canyon of the Gunnison    308962
# 7                   Bryce Canyon   2679478
# 8                    Canyonlands    739449
# 9                   Capitol Reef   1227627
# 10              Carlsbad Caverns    465912
# 11               Channel Islands    366250
# 12                      Congaree    145929
# 13                   Crater Lake    720659
# 14               Cuyahoga Valley   2096053
# 15                  Death Valley   1678660
# 16                        Denali    594660
# 17                  Dry Tortugas     56810
# 18                    Everglades    597124
# 19           Gates of the Arctic      9591
# 20                  Gateway Arch   2016180
# 21                       Glacier   2965309
# 22                   Glacier Bay    597915
# 23                  Grand Canyon   6380495
# 24                   Grand Teton   3491151
# 25                   Great Basin    153094
# 26              Great Sand Dunes    442905
# 27         Great Smoky Mountains  11421200
# 28           Guadalupe Mountains    172347
# 29                     Haleakalā   1044084
# ..                           ...       ...
# 31                   Hot Springs   1506887
# 32                 Indiana Dunes   1756079
# 33                   Isle Royale     25798
# 34                   Joshua Tree   2942382
# 35                        Katmai     37818
# 36                  Kenai Fjords    321596
# 37                  Kings Canyon    699023
# 38                  Kobuk Valley     14937
# 39                    Lake Clark     14479
# 40               Lassen Volcanic    499435
# 41                  Mammoth Cave    533206
# 42                    Mesa Verde    563420
# 43                 Mount Rainier   1518491
# 44                North Cascades     30085
# 45                       Olympic   3104455
# 46              Petrified Forest    644922
# 47                     Pinnacles    222152
# 48                       Redwood    482536
# 49                Rocky Mountain   4590493
# 50                       Saguaro    957405
# 51                       Sequoia   1229594
# 52                    Shenandoah   1264880
# 53            Theodore Roosevelt    749389
# 54                Virgin Islands    112287
# 55                     Voyageurs    239656
# 56                     Wind Cave    656397
# 57            Wrangell–St. Elias     79450
# 58                   Yellowstone   4115000
# 59                      Yosemite   4009436
# 60                          Zion   4320033
#
# [61 rows x 2 columns]
